# %% [markdown]
# # Análisis Exploratorio de Datos (EDA)
#
# Exploraremos los datos limpios para comprender las relaciones entre las variables de supervivenia.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('data/titanic_clean.csv')
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# # Supervivencia por Género

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Sex', y='Survived', data=df, palette='viridis')
plt.title('Probabilidad de Supervivencia por Género')
plt.show()
# Out:
# /var/folders/nn/jtbcdp494cd5mq2c9d88vlbc0000gn/T/ipykernel_47062/1505180528.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Sex', y='Survived', data=df, palette='viridis')

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Pclass', y= 'Survived', data=df, palette='magma')
plt.title('Probabilidad de Supervivencia por Clase')
plt.show()
# Out:
# /var/folders/nn/jtbcdp494cd5mq2c9d88vlbc0000gn/T/ipykernel_47062/3078854192.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Pclass', y= 'Survived', data=df, palette='magma')

# %% [markdown]
# # Distribución de Edades

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='Age', hue= 'Survived', kde=True, element='step')
plt.title('Distribución de Edad por Superviviencia')
plt.show()

# %% [markdown]
# # Ejercicios
#
# A continuación se resuelve una celda por cada pregunta del análisis exploratorio.

# %% [markdown]
# ## Ejercicio 1: Distribución de edades de los pasajeros

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', kde=True)
plt.title('Distribución de edades de los pasajeros')
plt.xlabel('Edad')
plt.ylabel('Cantidad')
plt.show()

# %% [markdown]
# ## Ejercicio 2: Sobrevivientes por clase de pasajero (Pclass)

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Pclass', hue='Survived', palette='viridis')
plt.title('Cantidad de sobrevivientes por clase de pasajero')
plt.xlabel('Clase (Pclass)')
plt.ylabel('Cantidad')
plt.legend(title='Supervivencia', labels=['No sobrevivió', 'Sí sobrevivió'])
plt.show()

# %% [markdown]
# ## Ejercicio 3: Sobrevivientes por género (Sex)

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Sex', hue='Survived', palette='magma')
plt.title('Cantidad de sobrevivientes por género')
plt.xlabel('Género')
plt.ylabel('Cantidad')
plt.legend(title='Supervivencia', labels=['No sobrevivió', 'Sí sobrevivió'])
plt.show()

# %% [markdown]
# ## Ejercicio 4: Sobrevivientes por puerto de embarque (Embarked)

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Embarked', hue='Survived', palette=['#240750', '#344C64'])
plt.title('Cantidad de sobrevivientes por puerto de embarque')
plt.xlabel('Puerto de embarque')
plt.ylabel('Cantidad')
plt.legend(title='Supervivencia', labels=['No sobrevivió', 'Sí sobrevivió'])
plt.show()

# %% [markdown]
# ## Ejercicio 5: Tasa de supervivencia por grupo de edad
# Agrupamos las edades en categorías (Infante, Niño, Adolescente, Joven Adulto, Adulto, Mayor).

# %%
bins = [0, 2, 12, 18, 35, 60, 120]
etiquetas = ['Infante', 'Niño', 'Adolescente', 'Joven Adulto', 'Adulto', 'Mayor']
grupo_edad = pd.cut(df['Age'], bins=bins, labels=etiquetas)

plt.figure(figsize=(10, 6))
sns.barplot(x=grupo_edad, y=df['Survived'], palette='viridis')
plt.title('Tasa de supervivencia por grupo de edad')
plt.xlabel('Grupo de edad')
plt.ylabel('Tasa de supervivencia')
plt.show()
# Out:
# /var/folders/nn/jtbcdp494cd5mq2c9d88vlbc0000gn/T/ipykernel_47062/681537125.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=grupo_edad, y=df['Survived'], palette='viridis')

# %% [markdown]
# ## Ejercicio 6: Conteo de pasajeros en cada clase (Pclass)

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Pclass', hue='Pclass', palette='crest', legend=False)
plt.title('Conteo de pasajeros por clase')
plt.xlabel('Clase (Pclass)')
plt.ylabel('Cantidad')
plt.show()

# %% [markdown]
# ## Ejercicio 7: Distribución de género dentro de cada clase (Pclass)

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Pclass', hue='Sex', palette='Set2')
plt.title('Distribución de género dentro de cada clase')
plt.xlabel('Clase (Pclass)')
plt.ylabel('Cantidad')
plt.legend(title='Género')
plt.show()

# %% [markdown]
# ## Ejercicio 8: Distribución de clase de pasajero por puerto de embarque (Embarked)

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Embarked', hue='Pclass', palette='magma')
plt.title('Distribución de clase por puerto de embarque')
plt.xlabel('Puerto de embarque')
plt.ylabel('Cantidad')
plt.legend(title='Clase')
plt.show()

# %% [markdown]
# ## Ejercicio 9: Conteo de pasajeros por género (Sex)

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Sex', hue='Sex', palette='pastel', legend=False)
plt.title('Conteo de pasajeros por género')
plt.xlabel('Género')
plt.ylabel('Cantidad')
plt.show()

# %% [markdown]
# ## Ejercicio 10: Valores máximo y mínimo de la edad

# %%
print(f"Edad máxima: {df['Age'].max()}")
print(f"Edad mínima: {df['Age'].min()}")
# Out:
# Edad máxima: 80.0
# Edad mínima: 0.42

# %% [markdown]
# ## Ejercicio 11: Distribución de edades con líneas de media, mediana y moda

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', kde=True)
plt.axvline(df['Age'].mean(), color='red', label='Media')
plt.axvline(df['Age'].median(), color='green', label='Mediana')
plt.axvline(df['Age'].mode()[0], color='black', label='Moda')
plt.title('Distribución de edades (media, mediana y moda)')
plt.xlabel('Edad')
plt.legend()
plt.show()

print(f"Media: {df['Age'].mean():.2f}")
print(f"Mediana: {df['Age'].median():.2f}")
print(f"Moda: {df['Age'].mode()[0]:.2f}")
# Out:
# Media: 28.94
# Mediana: 28.00
# Moda: 28.00

# %% [markdown]
# ## Ejercicio 12: Diagrama de caja (boxplot) de outliers en la edad

# %%
plt.figure(figsize=(10, 4))
sns.boxplot(x=df['Age'], color='skyblue')
plt.title('Boxplot de la edad (outliers)')
plt.xlabel('Edad')
plt.show()

# %% [markdown]
# ## Ejercicio 13: Valores máximo y mínimo de la tarifa (Fare)

# %%
print(f"Tarifa máxima: {df['Fare'].max()}")
print(f"Tarifa mínima: {df['Fare'].min()}")
# Out:
# Tarifa máxima: 512.3292
# Tarifa mínima: 0.0

# %% [markdown]
# ## Ejercicio 14: Distribución de tarifas con líneas de media, mediana y moda

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Fare', kde=True)
plt.axvline(df['Fare'].mean(), color='red', label='Media')
plt.axvline(df['Fare'].median(), color='green', label='Mediana')
plt.axvline(df['Fare'].mode()[0], color='black', label='Moda')
plt.title('Distribución de tarifas (media, mediana y moda)')
plt.xlabel('Tarifa (Fare)')
plt.legend()
plt.show()

print(f"Media: {df['Fare'].mean():.2f}")
print(f"Mediana: {df['Fare'].median():.2f}")
print(f"Moda: {df['Fare'].mode()[0]:.2f}")
# Out:
# Media: 32.20
# Mediana: 14.45
# Moda: 8.05

# %% [markdown]
# ## Ejercicio 15: Diagrama de caja (boxplot) de outliers en la tarifa (Fare)

# %%
plt.figure(figsize=(10, 4))
sns.boxplot(x=df['Fare'], color='salmon')
plt.title('Boxplot de la tarifa (outliers)')
plt.xlabel('Tarifa (Fare)')
plt.show()

# %% [markdown]
# ## Ejercicio 16: Pasajeros que pagaron 0 en tarifa

# %%
pasajeros_tarifa_cero = df[df['Fare'] == 0]
print(f'Cantidad de pasajeros con tarifa 0: {len(pasajeros_tarifa_cero)}')
pasajeros_tarifa_cero
# Out:
# Cantidad de pasajeros con tarifa 0: 15
#      Survived  Pclass   Sex   Age  SibSp  Parch  Fare Embarked
# 179         0       3  male  36.0      0      0   0.0        S
# 263         0       1  male  40.0      0      0   0.0        S
# 271         1       3  male  25.0      0      0   0.0        S
# 277         0       2  male  28.0      0      0   0.0        S
# 302         0       3  male  19.0      0      0   0.0        S
# 413         0       2  male  28.0      0      0   0.0        S
# 466         0       2  male  28.0      0      0   0.0        S
# 481         0       2  male  28.0      0      0   0.0        S
# 597         0       3  male  49.0      0      0   0.0        S
# 633         0       1  male  28.0      0      0   0.0        S
# 674         0       2  male  28.0      0      0   0.0        S
# 732         0       2  male  28.0      0      0   0.0        S
# 806         0       1  male  39.0      0      0   0.0        S
# ...

# %% [markdown]
# ## Ejercicio 17: Conteo de pasajeros por número de hermanos/esposos a bordo (SibSp)

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='SibSp', hue='SibSp', palette='flare', legend=False)
plt.title('Conteo de pasajeros por número de hermanos/esposos (SibSp)')
plt.xlabel('SibSp')
plt.ylabel('Cantidad')
plt.show()

# %% [markdown]
# ## Ejercicio 18: Tasa de supervivencia según el número de hermanos/esposos (SibSp)

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x='SibSp', y='Survived', palette='flare')
plt.title('Tasa de supervivencia por número de hermanos/esposos (SibSp)')
plt.xlabel('SibSp')
plt.ylabel('Tasa de supervivencia')
plt.show()
# Out:
# /var/folders/nn/jtbcdp494cd5mq2c9d88vlbc0000gn/T/ipykernel_47062/279896905.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='SibSp', y='Survived', palette='flare')

# %% [markdown]
# ## Ejercicio 19: Porcentaje de supervivencia para cada valor de SibSp

# %%
porcentaje_sibsp = df.groupby('SibSp')['Survived'].mean() * 100
print('Porcentaje de supervivencia por SibSp:')
print(porcentaje_sibsp.round(2))
# Out:
# Porcentaje de supervivencia por SibSp:
# SibSp
# 0    34.54
# 1    53.59
# 2    46.43
# 3    25.00
# 4    16.67
# 5     0.00
# 8     0.00
# Name: Survived, dtype: float64

# %% [markdown]
# ## Ejercicio 20: Mapa de calor (heatmap) de la matriz de correlación

# %%
plt.figure(figsize=(10, 8))
columnas_numericas = ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
sns.heatmap(df[columnas_numericas].corr(),
            annot=True,
            cbar=True,
            cmap='coolwarm',
            cbar_kws={'label': 'Nivel de correlación'})
plt.title('Matriz de correlación de variables numéricas')
plt.show()

# %%
df['Sex'] = df['Sex'].map({'male': 0, 'female':1})

df = pd.get_dummies(df, columns=['Embarked'], prefix='Emb')

df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Emb_C  Emb_Q  Emb_S
# 0         0       3    0  22.0      1      0   7.2500  False  False   True
# 1         1       1    1  38.0      1      0  71.2833   True  False  False
# 2         1       3    1  26.0      0      0   7.9250  False  False   True
# 3         1       1    1  35.0      1      0  53.1000  False  False   True
# 4         0       3    0  35.0      0      0   8.0500  False  False   True

# %%
df.to_csv('data/titanic_feature.csv', index= False)

print("Datos guardados en data/titanic_feature.csv")
# Out:
# Datos guardados en data/titanic_feature.csv

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

df = pd.read_csv('data/titanic_feature.csv')

x = df.drop('Survived', axis=1)
y = df['Survived']

# Dividir en entrenamiento y prueba (80/20), conservando la proporción de clases
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)
print(f'Entrenamiento: {x_train.shape[0]} filas | Prueba: {x_test.shape[0]} filas')
# Out:
# Entrenamiento: 712 filas | Prueba: 179 filas

# %% [markdown]
# # Modelado
#
# Entrenamos dos modelos de clasificación sobre las variables ya codificadas (`titanic_feature.csv`) y comparamos su desempeño.

# %% [markdown]
# ## Modelo 1: Random Forest

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

rf = RandomForestClassifier(n_estimators=100, max_depth=6, random_state=42)
rf.fit(x_train, y_train)
y_pred_rf = rf.predict(x_test)

print(f'Accuracy (Random Forest): {accuracy_score(y_test, y_pred_rf):.4f}')
print()
print('Reporte de clasificación:')
print(classification_report(y_test, y_pred_rf, target_names=['No sobrevivió', 'Sobrevivió']))

plt.figure(figsize=(6, 5))
sns.heatmap(confusion_matrix(y_test, y_pred_rf), annot=True, fmt='d', cmap='Blues',
            xticklabels=['No sobrevivió', 'Sobrevivió'],
            yticklabels=['No sobrevivió', 'Sobrevivió'])
plt.title('Matriz de confusión - Random Forest')
plt.xlabel('Predicción')
plt.ylabel('Real')
plt.show()
# Out:
# Accuracy (Random Forest): 0.8156
#
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
# No sobrevivió       0.79      0.95      0.86       110
#    Sobrevivió       0.88      0.61      0.72        69
#
#      accuracy                           0.82       179
#     macro avg       0.83      0.78      0.79       179
#  weighted avg       0.83      0.82      0.81       179

# %% [markdown]
# ## Modelo 2: Regresión Logística

# %%
lr = LogisticRegression(max_iter=2000, random_state=42)
lr.fit(x_train, y_train)
y_pred_lr = lr.predict(x_test)

print(f'Accuracy (Regresión Logística): {accuracy_score(y_test, y_pred_lr):.4f}')
print()
print('Reporte de clasificación:')
print(classification_report(y_test, y_pred_lr, target_names=['No sobrevivió', 'Sobrevivió']))

plt.figure(figsize=(6, 5))
sns.heatmap(confusion_matrix(y_test, y_pred_lr), annot=True, fmt='d', cmap='Greens',
            xticklabels=['No sobrevivió', 'Sobrevivió'],
            yticklabels=['No sobrevivió', 'Sobrevivió'])
plt.title('Matriz de confusión - Regresión Logística')
plt.xlabel('Predicción')
plt.ylabel('Real')
plt.show()
# Out:
# Accuracy (Regresión Logística): 0.7933
#
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
# No sobrevivió       0.80      0.88      0.84       110
#    Sobrevivió       0.78      0.65      0.71        69
#
#      accuracy                           0.79       179
#     macro avg       0.79      0.77      0.77       179
#  weighted avg       0.79      0.79      0.79       179

# %% [markdown]
# ## Comparación de modelos e importancia de variables

# %%
comparacion = pd.DataFrame({
    'Modelo': ['Random Forest', 'Regresión Logística'],
    'Accuracy': [accuracy_score(y_test, y_pred_rf), accuracy_score(y_test, y_pred_lr)]
})
print(comparacion.to_string(index=False))

# Importancia de variables según el Random Forest
importancias = pd.Series(rf.feature_importances_, index=x.columns).sort_values(ascending=False)
plt.figure(figsize=(10, 6))
sns.barplot(x=importancias.values, y=importancias.index, hue=importancias.index,
            palette='viridis', legend=False)
plt.title('Importancia de variables (Random Forest)')
plt.xlabel('Importancia')
plt.ylabel('Variable')
plt.show()
# Out:
#              Modelo  Accuracy
#       Random Forest  0.815642
# Regresión Logística  0.793296
